# %%
import pandas as pd

# %%
info = {
    "Name" : ["Haseeb", "Habib", "Abdullah"],
    "CGPA" : [3.4,3.2,2.3]
}

df = pd.DataFrame(info)
df
# Out:
#        Name  CGPA
# 0    Haseeb   3.4
# 1     Habib   3.2
# 2  Abdullah   2.3
