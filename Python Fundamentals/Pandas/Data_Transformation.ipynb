# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

# %%
df2 = df.copy()
df2["tax"] = df2["income"].apply(lambda x : "20%" if x >= 50000 else "10%")


gender_map = {"Male" : "M", "Female" : "F", "Unknown": "U"}
df2["gender"] = df["gender"].map(gender_map)


df2.assign(new_income = df2["income"] *1.1)

df2["country"].replace("USA", "PAK")

df2.columns = ["ID", "Name", "Age", "Country" , "Gender", "Income" , "Tax"]
df2.rename(columns={"Income" : "Salary"})
df2.rename(index = {1:"First"})
df2["Income"].sort_values()
df2.sort_values("Income")
sorted_df = df2.sort_values(["Income", "Age"])

sorted_df.sort_index()
sorted_df.reset_index()
sorted_df.reset_index(drop = True)

sorted_df["Ranking"] = sorted_df["Income"].rank()

# %%
sorted_df
# Out:
#     ID          Name   Age Country Gender   Income  Tax  Ranking
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0  10%     10.0
# 3    3          Alex   NaN     USA      U  47000.0  10%      9.0
# 5    5        Li Wei  27.0   China      M  51000.0  20%      8.0
# 0    1      John Doe  29.0     USA      M  55000.0  20%      6.5
# 1    1      John Doe  29.0     USA      M  55000.0  20%      6.5
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%      5.0
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%      3.5
# 2    2    Jane Smith   NaN  Canada      F  62000.0  20%      3.5
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0  20%      2.0
# 6    6           NaN  45.0   India      F  73000.0  20%      1.0
# 4    4  Maria Garcia  34.0   Spain      F      NaN  10%      NaN
